# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahferraz/colab-notebooks/blob/main/notebooks/An%C3%A1lise_Explorat%C3%B3ria_de_Dados_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Criando a tabela
dados = pd.DataFrame({
    "Nome": ["Ana", "João", "Maria", "Lucas", "Carla", "Paulo", "Bruna", "Marcos", "Júlia", "Fernanda"],
    "Idade": [25, 32, 28, 40, 29, 35, 27, 22, 30, 33],
    "Cidade": ["Salvador", "Salvador", "Feira", "Ilhéus", "Feira", "Salvador", "Itabuna", "Feira", "Ilhéus", "Salvador"],
    "Valor_gasto": [350, 420, 150, 1000, 200, 500, 250, 120, 800, 400]
})

print(dados.head())
print(dados.info())
print(dados.describe())
print(dados["Cidade"].value_counts())
# Out:
#     Nome  Idade    Cidade  Valor_gasto
# 0    Ana     25  Salvador          350
# 1   João     32  Salvador          420
# 2  Maria     28     Feira          150
# 3  Lucas     40    Ilhéus         1000
# 4  Carla     29     Feira          200
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nome         10 non-null     object
#  1   Idade        10 non-null     int64
#  2   Cidade       10 non-null     object
#  3   Valor_gasto  10 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 452.0+ bytes
# None
#            Idade  Valor_gasto
# count  10.000000    10.000000
# mean   30.100000   419.000000
# std     5.173651   285.324377
# min    22.000000   120.000000
# 25%    27.250000   212.500000
# 50%    29.500000   375.000000
# 75%    32.750000   480.000000
# max    40.000000  1000.000000
# Cidade
# Salvador    4
# Feira       3
# Ilhéus      2
# Itabuna     1
# Name: count, dtype: int64

# %%
sns.countplot(x="Cidade", data=dados)
plt.show()

# %%
sns.countplot(x="Cidade", data=dados, hue="Idade")
plt.show()

# %%
sns.barplot(x="Cidade", y="Valor_gasto", data=dados)
plt.show()

# %%
sns.boxplot(x="Cidade", y="Valor_gasto", data=dados)
plt.show()
